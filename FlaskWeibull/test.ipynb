# %%
import numpy as np

# %%
import flast_start as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-7bfc363d8fa2> in <module>()
# ----> 1 import flast_start as np
#
# ModuleNotFoundError: No module named 'flast_start'

# %%
# !pip list
# Out:
# Package                                 Version             Location
# --------------------------------------- ------------------- ----------------------------------------------
# absl-py                                 0.12.0
# alabaster                               0.7.12
# anaconda-client                         1.7.2
# anaconda-navigator                      1.9.12
# anaconda-project                        0.8.3
# antlr4-python3-runtime                  4.8
# appdirs                                 1.4.4
# applaunchservices                       0.2.1
# appnope                                 0.1.0
# appscript                               1.0.1
# argh                                    0.26.2
# argon2-cffi                             20.1.0
# arviz                                   0.11.4
# asn1crypto                              1.3.0
# astor                                   0.8.1
# astroid                                 2.3.3
# astropy                                 4.0
# ...
